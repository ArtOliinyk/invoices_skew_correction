# %%
from invoice_rotation import tesseract_init, get_rotation_angle, rotate_and_save

# %%
tesseract_init(r'C:\Program Files\Tesseract-OCR\tesseract.exe')

# %%
angle = get_rotation_angle("invoices_rotated/2.png")
angle
# Out:
# -9.224620501606255

# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
imge = Image.open('invoices_rotated/2.png')
plt.imshow(imge)

# %%
imge = Image.open('invoices_rotated/2.png')
plt.imshow(imge)
